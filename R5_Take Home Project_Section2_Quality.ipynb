# %% [markdown]
# # **Second section**
#
#
# *   Hacer un análisis de calidad de datos sobre *dataset.csv*
# *   Generar un reporte de los resultados.
#
# ### Note:  encontrar todas las anomalías de calidad de datos del dataset. No deberá corregir las anomalías que encuentre, solo encontrarlas y justificarlas en el reporte.
# Entregable: Reporte de calidad de datos del dataset, adicionalmente puede incluir el código que muestre cómo encontró las anomalías de calidad de datos.

# %%
## Importing libraries

import pandas as pd
import json

# %%
## Mounting Google Drive in the Colab environment:

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Path to the CSV file
file_path = '/content/drive/My Drive/Python/R5/dataset.csv'

# Read the CSV file into a DataFrame named 'dataset'
df = pd.read_csv(file_path)

df.head(3)
# Out:
#    disc_number  duration_ms explicit  track_number  track_popularity  \
# 0            1       212600    False             1                77
# 1            1       231833    False             2                78
# 2            1       231000    False             3                79
#
#                  track_id                              track_name  \
# 0  4WUepByoeqcedHoYhSNHRt  Welcome To New York (Taylor's Version)
# 1  0108kcWLnn2HlH2kedi1gn          Blank Space (Taylor's Version)
# 2  3Vpk1hfMAQme8VJ0SNRSkd                Style (Taylor's Version)
#
#    audio_features.danceability  audio_features.energy  audio_features.key  \
# 0                        0.757                  0.610                 7.0
# 1                        0.733                  0.733                 0.0
# 2                        0.511                  0.822                11.0
#
#    ...  audio_features.tempo       audio_features.id  \
# 0  ...               116.998  4WUepByoeqcedHoYhSNHRt
# 1  ...                96.057  0108kcWLnn2HlH2kedi1gn
# 2  ...                94.868  3Vpk1hfMAQme8VJ0SNRSkd
#
#    audio_features.time_signature           artist_id   artist_name  \
# 0                            4.0  06HL4z0CvFAxyc27GX  Taylor Swift
# 1                            4.0  06HL4z0CvFAxyc27GX  Taylor Swift
# 2                            4.0  06HL4z0CvFAxyc27GX  Taylor Swift
#
#    artist_popularity                album_id  \
# 0                120  1o59UpKw81iHR0HPiSkJR0
# 1                120  1o59UpKw81iHR0HPiSkJR0
# 2                120  1o59UpKw81iHR0HPiSkJR0
#
#                          album_name album_release_date  album_total_tracks
# 0  1989 (Taylor's Version) [Deluxe]         2023-10-27                  22
# 1  1989 (Taylor's Version) [Deluxe]         2023-10-27                  22
# 2  1989 (Taylor's Version) [Deluxe]         2023-10-27                  22
#
# [3 rows x 27 columns]

# %% [markdown]
# # 1. Completeness: Checking for any null or missing values

# %% [markdown]
# #### Analysis

# %%
## Calculating the percentage of missing values for each column
total_rows = len(df)
percentage_missing = (df.isnull().sum() / total_rows) * 100

## Creating a new DataFrame with both the count and percentage of missing values
completeness_report = pd.DataFrame({
    'Missing Values': df.isnull().sum(),
    'Percentage of Missing Values': percentage_missing
})

completeness_report
# Out:
#                                  Missing Values  Percentage of Missing Values
# disc_number                                   0                      0.000000
# duration_ms                                   0                      0.000000
# explicit                                      0                      0.000000
# track_number                                  0                      0.000000
# track_popularity                              0                      0.000000
# track_id                                      8                      1.484230
# track_name                                    7                      1.298701
# audio_features.danceability                   2                      0.371058
# audio_features.energy                         2                      0.371058
# audio_features.key                            1                      0.185529
# audio_features.loudness                       2                      0.371058
# audio_features.mode                           0                      0.000000
# audio_features.speechiness                    1                      0.185529
# audio_features.acousticness                   1                      0.185529
# audio_features.instrumentalness               0                      0.000000
# audio_features.liveness                       1                      0.185529
# audio_features.valence                        0                      0.000000
# audio_features.tempo                          1                      0.185529
# audio_features.id                             0                      0.000000
# audio_features.time_signature                 1                      0.185529
# artist_id                                     0                      0.000000
# artist_name                                   0                      0.000000
# artist_popularity                             0                      0.000000
# album_id                                      0                      0.000000
# album_name                                   62                     11.502783
# album_release_date                            0                      0.000000
# album_total_tracks                            0                      0.000000

# %%
## Generate the report
print("The dataset has missing values in several columns:\n")
for index, row in completeness_report[completeness_report['Missing Values'] > 0].iterrows():
  print("\t"f"{index}: {int(row['Missing Values'])} missing values ({row['Percentage of Missing Values']:.2f}%)")
# Out:
# The dataset has missing values in several columns:
#
# 	track_id: 8 missing values (1.48%)
# 	track_name: 7 missing values (1.30%)
# 	audio_features.danceability: 2 missing values (0.37%)
# 	audio_features.energy: 2 missing values (0.37%)
# 	audio_features.key: 1 missing values (0.19%)
# 	audio_features.loudness: 2 missing values (0.37%)
# 	audio_features.speechiness: 1 missing values (0.19%)
# 	audio_features.acousticness: 1 missing values (0.19%)
# 	audio_features.liveness: 1 missing values (0.19%)
# 	audio_features.tempo: 1 missing values (0.19%)
# 	audio_features.time_signature: 1 missing values (0.19%)
# 	album_name: 62 missing values (11.50%)

# %% [markdown]
# #### Report

# %% [markdown]
# The dataset has missing values in several columns:
#
# 	track_id: 8 missing values (1.48%)
# 	track_name: 7 missing values (1.30%)
# 	audio_features.danceability: 2 missing values (0.37%)
# 	audio_features.energy: 2 missing values (0.37%)
# 	audio_features.key: 1 missing values (0.19%)
# 	audio_features.loudness: 2 missing values (0.37%)
# 	audio_features.speechiness: 1 missing values (0.19%)
# 	audio_features.acousticness: 1 missing values (0.19%)
# 	audio_features.liveness: 1 missing values (0.19%)
# 	audio_features.tempo: 1 missing values (0.19%)
# 	audio_features.time_signature: 1 missing values (0.19%)
# 	album_name: 62 missing values (11.50%)

# %% [markdown]
# # 2. Consistency: Examine the dataset for any inconsistencies (**Logical** inconsistencies in this case.)

# %% [markdown]
# #### Analysis

# %%
# Calculate the number of unique values in each column
unique_value_counts = df.nunique()

print(unique_value_counts)
# Out:
# disc_number                          2
# duration_ms                        364
# explicit                             4
# track_number                        46
# track_popularity                    73
# track_id                           512
# track_name                         331
# audio_features.danceability        267
# audio_features.energy              348
# audio_features.key                  12
# audio_features.loudness            448
# audio_features.mode                  2
# audio_features.speechiness         292
# audio_features.acousticness        401
# audio_features.instrumentalness    240
# audio_features.liveness            271
# audio_features.valence             326
# audio_features.tempo               450
# audio_features.id                  519
# audio_features.time_signature        3
# artist_id                            1
# artist_name                          1
# artist_popularity                    1
# album_id                            26
# album_name                          24
# album_release_date                  23
# album_total_tracks                  17
# dtype: int64

# %%
# Aply value_counts() to each column
for column in df.columns:
    counts = df[column].value_counts()
    # Mostrar todos los valores y recuentos
    # with pd.option_context('display.max_rows', None):
    print(f"Value counts for {column}:\n{counts}\n\n\n")
# Out:
# Value counts for disc_number:
# 1    522
# 2     17
# Name: disc_number, dtype: int64
#
#
#
# Value counts for duration_ms:
# 231000    6
# 212600    5
# 247533    5
# 235800    5
# 271000    4
#          ..
# 290040    1
# 214373    1
# 221800    1
# 199733    1
# 179066    1
# Name: duration_ms, Length: 364, dtype: int64
#
#
#
# Value counts for explicit:
# False    480
# True      54
# No         4
# Si         1
# Name: explicit, dtype: int64
#
#
#
# Value counts for track_number:
# 8     29
# 1     28
# 6     28
# 7     28
# 2     28
# 5     28
# 3     28
# 4     28
# 11    27
# 12    27
# 13    27
# 10    27
# 9     27
# 14    25
# 15    24
# 16    21
# 17    18
# 18    14
# 19    12
# 20    10
# 21    10
# 22     8
# 23     4
# 26     3
# 24     3
# 25     3
# 28     2
# 29     2
# 30     2
# 27     2
# 39     1
# 45     1
# 44     1
# 43     1
# 42     1
# 41     1
# 40     1
# 36     1
# 38     1
# 37     1
# 35     1
# 34     1
# 33     1
# 32     1
# 31     1
# 46     1
# Name: track_number, dtype: int64
#
#
#
# Value counts for track_popularity:
#  70    24
#  72    20
#  82    18
#  80    18
#  76    17
#        ..
# -70     1
# -92     1
# -75     1
# -71     1
#  30     1
# Name: track_popularity, Length: 73, dtype: int64
#
#
#
# Value counts for track_id:
# 1fzAuUVbzlhZ1lJAx9PtY6    2
# 2dgFqt3w9xIQRjhPtwNk3D    2
# 1dGr1c8CrMLDpV6mPbImSI    2
# 3pHkh7d0lzM2AldUtz2x37    2
# 2YWtcWi3a83pdEg3Gif4Pd    2
#                          ..
# 01QdEx6kFr78ZejhQtWR5m    1
# 0tQ9vBYpldCuikPsbgOVKA    1
# 2m3ObD945KvpE5y9A1eUWm    1
# 3ExweHKZF9B752DPQByRVT    1
# 1hxLyjC9D9Jpw6EAPKqWv4    1
# Name: track_id, Length: 512, dtype: int64
#
#
#
# Value counts for track_name:
# The Story Of Us                                     4
# Sweet Nothing                                       3
# Lavender Haze                                       3
# Question...?                                        3
# Midnight Rain                                       3
#                                                    ..
# Don’t You (Taylor’s Version) (From The Vault)       1
# Bye Bye Baby (Taylor’s Version) (From The Vault)    1
# right where you left me - bonus track               1
# it’s time to go - bonus track                       1
# Teardrops on My Guitar - Pop Version                1
# Name: track_name, Length: 331, dtype: int64
#
#
#
# Value counts for audio_features.danceability:
# 0.602    9
# 0.610    7
# 0.535    6
# 0.649    6
# 0.546    6
#         ..
# 0.460    1
# 0.693    1
# 0.440    1
# 0.645    1
# 0.668    1
# Name: audio_features.danceability, Length: 267, dtype: int64
#
#
#
# Value counts for audio_features.energy:
# 0.634    6
# 0.488    6
# 0.777    5
# 0.386    5
# 0.747    5
#         ..
# 0.200    1
# 0.781    1
# 0.344    1
# 0.155    1
# 0.753    1
# Name: audio_features.energy, Length: 348, dtype: int64
#
#
#
# Value counts for audio_features.key:
# 0.0     97
# 7.0     95
# 5.0     66
# 4.0     62
# 2.0     58
# 9.0     38
# 1.0     26
# 6.0     24
# 8.0     23
# 10.0    22
# 11.0    14
# 3.0     13
# Name: audio_features.key, dtype: int64
#
#
#
# Value counts for audio_features.loudness:
# -10.813    4
# -6.112     3
# -4.991     3
# -5.797     3
# -6.942     3
#           ..
# -7.673     1
# -5.864     1
# -5.098     1
# -7.138     1
# -3.827     1
# Name: audio_features.loudness, Length: 448, dtype: int64
#
#
#
# Value counts for audio_features.mode:
# 1    492
# 0     47
# Name: audio_features.mode, dtype: int64
#
#
#
# Value counts for audio_features.speechiness:
# 0.0275    7
# 0.0308    6
# 0.0264    6
# 0.0281    5
# 0.0273    5
#          ..
# 0.0517    1
# 0.0666    1
# 0.0518    1
# 0.1540    1
# 0.0246    1
# Name: audio_features.speechiness, Length: 292, dtype: int64
#
#
#
# Value counts for audio_features.acousticness:
# 0.10100    5
# 0.13000    5
# 0.82900    3
# 0.81900    3
# 0.29800    3
#           ..
# 0.66300    1
# 0.00955    1
# 0.04940    1
# 0.07500    1
# 0.04020    1
# Name: audio_features.acousticness, Length: 401, dtype: int64
#
#
#
# Value counts for audio_features.instrumentalness:
# 0           235
# 2.06e-05      4
# 2.67e-05      3
# 1.64e-06      3
# 2.46e-05      3
#            ...
# 1.02e-05      1
# 1.86e-06      1
# 0.00218       1
# 9.19e-05      1
# 0.000807      1
# Name: audio_features.instrumentalness, Length: 240, dtype: int64
#
#
#
# Value counts for audio_features.liveness:
# 0.1080    13
# 0.1110    12
# 0.1010    11
# 0.1060    11
# 0.1150    10
#           ..
# 0.0925     1
# 0.0858     1
# 0.2210     1
# 0.1910     1
# 0.0863     1
# Name: audio_features.liveness, Length: 271, dtype: int64
#
#
#
# Value counts for audio_features.valence:
# 0.545    7
# 0.374    5
# 0.472    5
# 0.328    5
# 0.211    5
#         ..
# 0.410    1
# 0.443    1
# 0.581    1
# 0.205    1
# 0.504    1
# Name: audio_features.valence, Length: 326, dtype: int64
#
#
#
# Value counts for audio_features.tempo:
# 109.993    3
# 119.997    3
# 182.162    2
# 106.026    2
# 114.985    2
#           ..
# 208.918    1
# 125.089    1
# 125.952    1
# 78.915     1
# 199.997    1
# Name: audio_features.tempo, Length: 450, dtype: int64
#
#
#
# Value counts for audio_features.id:
# 4y5bvROuBDPr5fuwXbIBZR    2
# 1SymEzIT3H8UZfibCs3TYi    2
# 5hQSXkFgbxjZo9uCwd11so    2
# 4AYtqFyFbX0Xkc2wtcygTr    2
# 1LLXZFeAHK9R4xUramtUKw    2
#                          ..
# 51A8eKvvZz9uydvIZ7xRSV    1
# 1n2wszmJyVkw6FHqyLnQsY    1
# 01QdEx6kFr78ZejhQtWR5m    1
# 0tQ9vBYpldCuikPsbgOVKA    1
# 1hxLyjC9D9Jpw6EAPKqWv4    1
# Name: audio_features.id, Length: 519, dtype: int64
#
#
#
# Value counts for audio_features.time_signature:
# 4.0    517
# 3.0     14
# 5.0      7
# Name: audio_features.time_signature, dtype: int64
#
#
#
# Value counts for artist_id:
# 06HL4z0CvFAxyc27GX    539
# Name: artist_id, dtype: int64
#
#
#
# Value counts for artist_name:
# Taylor Swift    539
# Name: artist_name, dtype: int64
#
#
#
# Value counts for artist_popularity:
# 120    539
# Name: artist_popularity, dtype: int64
#
#
#
# Value counts for album_id:
# 1MPAXuTVL2Ej5x0JHiSPq8    46
# 1NAmidJlEaVgA3MpcPFYGq    36
# 0PZ7lAru5FDFHuirTkWe9Z    34
# 6kZ42qRrzov54LcAk4onW9    30
# 4hDok0OAJd57SGIT8xuWJH    26
# 1fnJ7k0bllNfL1kVdNVW1A    24
# 6S6JQWzUrJVcJLK4fi74Fw    22
# 1KVKqWeRuXsJDLTW0VuD29    22
# 1o59UpKw81iHR0HPiSkJR0    22
# 5AEDGbliTTfjOB8TSm1sxt    22
# 64LU4c1nfjz1t4VnGhagcg    21
# 3lS1y25WAhcqJDATJK70Mq    20
# 1yGbNOtRIgdIiGHOEBaZWf    19
# 2gP2LMVcIFgVczSJqn340t    19
# 1pzvBxYgT6OVwJLtHkrdQK    17
# 6AORtDjduMM3bupSWzbTSG    17
# 2fenSS68JI1h4Fo296JfGr    16
# 6DEjYFkNZh67HP7R9PSZvv    16
# 08CWGiv27MVQhYpuTtvx83    16
# 6fyR4wBPwLHKcRtxgd4sGh    16
# 2Xoteh7uEpea4TohMxjtaq    15
# 5eyZZoQEFQWRHkV2xgAeBw    15
# 6Ar2o9KCqcyYF9J0aQP3au    14
# 151w1FgRZfnKZA9FEcg9Z3    13
# 5fy0X0JmZRZnVa2UEicIOl    13
# 1ycoesYxIFymXWebfmz828     8
# Name: album_id, dtype: int64
#
#
#
# Value counts for album_name:
# Lover                                                                                  36
# folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]    34
# Red (Taylor's Version)                                                                 30
# Fearless (Taylor's Version)                                                            26
# Midnights (The Til Dawn Edition)                                                       24
# 1989 (Taylor's Version) [Deluxe]                                                       22
# Red (Deluxe Edition)                                                                   22
# Speak Now (Taylor's Version)                                                           22
# Speak Now (Deluxe Package)                                                             22
# 1989 (Taylor's Version)                                                                21
# Midnights (3am Edition)                                                                20
# Fearless (Platinum Edition)                                                            19
# 1989 (Deluxe)                                                                          19
# evermore (deluxe version)                                                              17
# folklore (deluxe version)                                                              17
# Fearless (International Version)                                                       16
# folklore                                                                               16
# reputation                                                                             16
# evermore                                                                               15
# Taylor Swift                                                                           15
# Speak Now                                                                              14
# 1989                                                                                   13
# Midnights                                                                              13
# Live From Clear Channel Stripped 2008                                                   8
# Name: album_name, dtype: int64
#
#
#
# Value counts for album_release_date:
# 2017-11-09    46
# 2019-08-23    36
# 2008-11-11    35
# 2020-11-25    34
# 2014-01-01    32
# 2021-11-12    30
# 2010-10-25    30
# 2021-04-09    26
# 2027-05-26    24
# 2023-10-27    22
# 2023-07-07    22
# 2010-01-01    22
# 2012-10-22    22
# 2023-10-26    21
# 2022-10-22    20
# 2020-08-18    17
# 2021-01-07    17
# 2017-11-10    16
# 2020-07-24    16
# 2020-12-11    15
# 1989-10-24    15
# 2022-10-21    13
# 2008-06-28     8
# Name: album_release_date, dtype: int64
#
#
#
# Value counts for album_total_tracks:
# 22          88
# 34          64
# 16          48
# 46          46
# 19          38
# 18          36
# 17          34
# 13          26
# 26          26
# 24          24
# 21          21
# 20          20
# 15          16
# 10          15
# Thirteen    15
# 14          14
# 8            8
# Name: album_total_tracks, dtype: int64

# %%
track_popularity_value_counts = df['track_popularity'].value_counts().reset_index()
track_popularity_value_counts.columns = ['Valor', 'Recuento']

# Mostrar todos los valores y recuentos
with pd.option_context('display.max_rows', None):
    print(track_popularity_value_counts)
# Out:
#     Valor  Recuento
# 0      70        24
# 1      72        20
# 2      82        18
# 3      80        18
# 4      76        17
# 5      78        17
# 6      68        16
# 7      71        16
# 8      74        15
# 9      77        15
# 10     60        15
# 11     73        13
# 12     69        12
# 13     84        12
# 14     83        11
# 15     49        11
# 16     47        11
# 17     36        11
# 18     58        10
# 19     66        10
# 20     33        10
# 21     81        10
# 22     75        10
# 23     67         9
# 24     50         9
# 25     53         9
# 26     37         9
# 27     79         8
# 28     51         8
# 29     56         8
# 30     48         8
# 31     85         8
# 32     34         7
# 33     59         7
# 34     61         7
# 35     55         6
# 36     87         6
# 37     46         6
# 38     65         6
# 39     43         5
# 40     40         5
# 41     42         5
# 42     35         5
# 43     54         5
# 44     64         5
# 45     86         5
# 46     62         4
# 47     44         4
# 48     52         4
# 49     45         4
# 50     88         4
# 51     57         4
# 52     32         3
# 53     63         3
# 54     91         3
# 55      0         3
# 56     38         3
# 57     39         3
# 58     41         2
# 59     90         2
# 60     92         2
# 61     99         2
# 62    152         1
# 63     31         1
# 64    -85         1
# 65     89         1
# 66     94         1
# 67    -69         1
# 68    -70         1
# 69    -92         1
# 70    -75         1
# 71    -71         1
# 72     30         1

# %% [markdown]
# #### Report

# %% [markdown]
# *   The **explicit** column has values like 'False', 'True', 'Si', 'No'. The presence of both English and Spanish values ('Si', 'No') for a boolean field indicates inconsistency.
#
# * The set of possible values for the **track_popularity** field is presumably {0, 1, 2, 3, ..., 100}. If this is true, all different values imply data inconsistency.

# %% [markdown]
# # 3. Conformity: Validate that all data is in the correct format and adheres to specific standards.

# %% [markdown]
# # 4. Accuracy: This dimension is challenging to assess without an external source of truth but will look for indicators of inaccuracy.

# %% [markdown]
# # 5. Integrity: Assess the integrity of relationships within the dataset.

# %% [markdown]
# # 6. Timeliness: Evaluate the relevance and currency of the data, particularly focusing on date fields.
